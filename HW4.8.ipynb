# %% [markdown]
# <div>
#     <h1 style="margin-top: 50px; font-size: 33px; text-align: center">Homework 4 - Does basic house information reflect house descriptions?</h1>
#     <br>
#     <div style="font-weight:200; font-size: 20px; padding-bottom: 15px; width: 100%; text-align: center;">
#         <right>Davide Toma, Giacomo Lo Cascio, Musie </right>
#         <br>
#     </div>
#     <hr>
# </div>

# %% [markdown]
# First of all we import all the libraries we need and we have to initialize the empty dataframe.

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
import time
import math
import pickle
import numpy as np

from sklearn.cluster import KMeans
from matplotlib import pyplot as plt


import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
#import num2words

from wordcloud import WordCloud,STOPWORDS
from PIL import Image
from string import punctuation

# %%
df = pd.DataFrame(columns=["Title", "Price","Locali","Superficie","Bagni","Piano","Description"])
address =  "https://www.immobiliare.it/vendita-case/roma/?criterio=rilevanza&pag="
page = "https://www.immobiliare.it/"

# %% [markdown]
# Now we have to fill the empty dataframe by doing web scraping and using the library BeautifulSoup. The website we have to scrape is www.immobiliare.it , a website where houses are sold.

# %%
count=0
row=0
for i in range(1,651):
    address = "https://www.immobiliare.it/vendita-case/roma/?criterio=rilevanza&pag="+str(i)
    url = requests.get(address)
    page =BeautifulSoup(url.text, 'lxml') 
    x = page.findAll('ul',{'class','annunci-list'})[0]
    
    types = ["vetrina","star","top","premium"]
    
    for t in types:
        
        for y in x.find_all('li', {'class', 'listing-item '+t+' js-row-detail'}):
            try:
                content = y.find('div',class_='listing-item_body--content')
                title = content.p.a.attrs
                if title['href'][:5]=="https":
                    site= title["href"]
                else:
                    site = 'https://www.immobiliare.it' + title['href']
                url2 = requests.get(site)
                page2 = BeautifulSoup(url2.text, 'lxml')
                descr = page2.find('div',class_='col-xs-12 description-text text-compressed')
                description = descr.div.text.strip()
                price = content.find('li', class_='lif__item lif__pricing').text
                locali_superficie = content.find_all(class_= 'text-bold')
                locali = locali_superficie[0].text
                superficie = locali_superficie[1].text
                bagni = locali_superficie[2].text
                piano = locali_superficie[3].text.strip()
                if len(piano)>3:
                    raise
                
                df.loc[row] = [title['title'],price.strip(),locali,superficie,bagni,piano,description]
                row+=1

            except:
                #print("Not considering a column")
                count+=1

# %% [markdown]
# We write a .csv file to have the dataframe without rerunning every time the code of the web scraping.

# %%
df.to_csv("dataset.csv")

# %%
print(row)
df.head()
# Out:
# 12453
#                                                Title  \
# 0  Bilocale viale Italo Calvino, Fonte Ostiense, ...
# 1  Bilocale via Ezio Sciamanna 12, Torrevecchia, ...
# 2  Attico / Mansarda via Taranto 100, San Giovann...
# 3  Attico / Mansarda via Degli Orti Di Galba, Mon...
# 4  Appartamento via San Sotero, Gregorio VII - Pi...
#
#                        Price Locali Superficie Bagni Piano  \
# 0                  € 225.000     2          50    1      1
# 1  € 159.000€ 169.000(-5.9%)     2          65    1      R
# 2                  € 459.000     2          85    1      A
# 3                  € 850.000     5         175    2      A
# 4                € 1.100.000    5+         225   3+      3
#
#                                          Description
# 0  PAPILLO EUR in elegante complesso residenziale...
# 1  Rif: 18083 - TORREVECCHIA - Via Ezio Sciamanna...
# 2  San Giovanni, Attico in Vendita, via Taranto l...
# 3  Nel quartiere Monteverde, a poche decine di me...
# 4  Gregorio Settimo - San Damaso \nNelle immediat...

# %% [markdown]
# # PART-1: CLUSTERING

# %% [markdown]
# Now we work loading the csv file.

# %% [markdown]
# We consider only 10000 rows, to make sure that every process does not take too much time, as the task involved obtaining at least 10,000 documents from web scraping (we have obtained more than 12,000), but to work from this point on, we can consider exactly 10,000 lines of the data frame.
#
# Let's take a look to the dataframe.

# %%
df = pd.read_csv('dataset.csv')

# %%
df = df[:10000]
df
# Out:
#       Unnamed: 0                                              Title  \
# 0              0  Bilocale viale Italo Calvino, Fonte Ostiense, ...
# 1              1  Bilocale via Ezio Sciamanna 12, Torrevecchia, ...
# 2              2  Attico / Mansarda via Taranto 100, San Giovann...
# 3              3  Attico / Mansarda via Degli Orti Di Galba, Mon...
# 4              4  Appartamento via San Sotero, Gregorio VII - Pi...
# 5              5  Trilocale via Raffaele De Ferrari 60, Borghesi...
# 6              6     Trilocale via delle Palme 16, Centocelle, Roma
# 7              7  Attico / Mansarda piazzale Clodio, 12, Mazzini...
# 8              8  Bilocale via Silicella 17, Tor Tre Teste - Tor...
# 9              9  Appartamento via Edoardo Jenner 163, Colli Por...
# 10            10                           Ufficio in Vendita, Roma
# 11            11  Appartamento viale delle Mura Gianicolensi, Mo...
# 12            12  Quadrilocale viale Bruno Pelizzi 281, Cinecitt...
# 13            13  Quadrilocale via Mario Ridolfi 32, Pisana - Br...
# 14            14  Appartamento via Courmayeur, Cortina d'Ampezzo...
# 15            15  Appartamento via dei Gandolfi, Camilluccia - F...
# 16            16  Appartamento via del Calice, Appio Claudio - S...
# 17            17          Bilocale via Savona, Villa Fiorelli, Roma
# 18            18     Appartamento viale dell'Aeronautica, Eur, Roma
# 19            19            Appartamento piazza Cavour, Prati, Roma
# 20            20  Attico / Mansarda viale Ezra Pound, Talenti - ...
# 21            21  Bilocale via Mario Musco 82, Ardeatino - Monta...
# 22            22   Quadrilocale viale Tito Labieno, Cinecittà, Roma
# 23            23  Trilocale via Pietro Rovetti 166, Torpignattar...
# 24            24  Attico / Mansarda via degli Armenti 70, Tor Sa...
# 25            25     Appartamento via Sesto Rufo 42, Balduina, Roma
# 26            26   Appartamento via di Pietralata, Pietralata, Roma
# 27            27       Trilocale via Columella, Torpignattara, Roma
# 28            28  Trilocale via della Camilluccia 273, Camillucc...
# 29            29  Bilocale via Ignazio Ribotti, Villa Bonelli, Roma
# ...          ...                                                ...
# 9970        9970         Bilocale via dei Platani, Centocelle, Roma
# 9971        9971  Quadrilocale viale dei Romanisti, Alessandrino...
# 9972        9972  Trilocale via del maggiolino, Tor Sapienza - L...
# 9973        9973  Attico / Mansarda via dei Frassini, Centocelle...
# 9974        9974           Bilocale via Fortebraccio, Pigneto, Roma
# 9975        9975          Bilocale via Salorno 64, Infernetto, Roma
# 9976        9976          Bilocale via pompei 0, San Giovanni, Roma
# 9977        9977    Bilocale piazza Sanmicheli, Torpignattara, Roma
# 9978        9978           Trilocale borgo borgo pio 0, Borgo, Roma
# 9979        9979       Bilocale via Adelaide Ristori, Parioli, Roma
# 9980        9980  Trilocale via val di non, Conca d'Oro - Valli,...
# 9981        9981  Appartamento via Pasubio, Mazzini - Delle Vitt...
# 9982        9982  Attico / Mansarda piazza Giovenale, Balduina, ...
# 9983        9983         Quadrilocale via Valbondione, Labaro, Roma
# 9984        9984  Trilocale via Enrico Cruciani Alibrandi 78, Po...
# 9985        9985  Quadrilocale via veglia 31, Conca d'Oro - Vall...
# 9986        9986  Attico / Mansarda via privata via alfredo fusc...
# 9987        9987    Trilocale via Casalmonferrato, Re di Roma, Roma
# 9988        9988  Quadrilocale via Diego Simonetti 54, Ostia Lev...
# 9989        9989  Trilocale via robert musil 8, Talenti - Monte ...
# 9990        9990       Trilocale via delle Mimose, Centocelle, Roma
# 9991        9991  Trilocale via Fosso del Poggio 4, Grottarossa ...
# 9992        9992  Bilocale via al Sesto Miglio, Tomba di Nerone,...
# 9993        9993        Bilocale via Gradoli, Tomba di Nerone, Roma
# 9994        9994      Trilocale via del Fiume Giallo, Torrino, Roma
# 9995        9995    Bilocale via Gradoli 100, Tomba di Nerone, Roma
# 9996        9996  Attico / Mansarda via Gradoli, Tomba di Nerone...
# 9997        9997      Quadrilocale piazza Tuscolo, Re di Roma, Roma
# 9998        9998      Trilocale via Lubriano, Tomba di Nerone, Roma
# 9999        9999      Trilocale via Cesare Beccaria, Flaminio, Roma
#
#                           Price Locali  Superficie Bagni Piano  \
# 0                     € 225.000     2         50.0    1      1
# 1     € 159.000€ 169.000(-5.9%)     2         65.0    1      R
# 2                     € 459.000     2         85.0    1      A
# 3                     € 850.000     5        175.0    2      A
# 4                   € 1.100.000    5+        225.0   3+      3
# 5     € 119.000€ 129.000(-7.8%)     3         85.0    1      2
# 6                     € 149.000     3         75.0    1      1
# 7                   € 1.300.000     4        115.0    2      9
# 8                     € 115.000     2         58.0    1      3
# 9                     € 695.000    5+        250.0    3      3
# 10                  € 1.220.000    5+        245.0    2      T
# 11                  € 1.380.000    5+        140.0    2      2
# 12                    € 370.000     4        139.0    2      5
# 13                    € 359.000     4        130.0    3      3
# 14                    € 650.000    5+        170.0    3      1
# 15                    € 800.000    5+        220.0    3      4
# 16                    € 650.000    5+        193.0    3      4
# 17                    € 339.000     2         70.0    1      3
# 18                  € 1.100.000    5+        250.0   3+      1
# 19                    € 950.000     5        170.0    1      3
# 20                    € 940.000    5+        200.0    3      A
# 21                    € 259.000     2         55.0    1      A
# 22                    € 460.000     4        110.0    2      1
# 23                    € 165.000     3         60.0    1      A
# 24                    € 189.000     4        110.0    2      A
# 25                  € 1.080.000    5+        250.0   3+      3
# 26                    € 395.000    5+        130.0    2      1
# 27                    € 125.000     3         50.0    1      T
# 28                    € 440.000     3        130.0    2      T
# 29    € 139.000€ 149.000(-6.7%)     2         60.0    1      T
# ...                         ...    ...         ...   ...   ...
# 9970                  € 130.000     2         60.0    1      T
# 9971                  € 239.000     4        128.0    2      2
# 9972                  € 199.000     3         80.0    2      2
# 9973                  € 220.000     4         95.0    1      A
# 9974                   € 98.000     2         55.0    1      S
# 9975                  € 125.000     2         48.0    1      1
# 9976                  € 199.000     2         75.0    1      S
# 9977                  € 150.000     2         55.0    1      5
# 9978                  € 690.000     3        100.0    2      3
# 9979                  € 495.000     2         75.0    2      T
# 9980                  € 125.000     3         60.0    1      T
# 9981                  € 860.000    5+        200.0    2      1
# 9982                  € 660.000     4        158.0    2      4
# 9983                  € 279.000     4        110.0    2      2
# 9984                  € 250.000     3         77.0    2      T
# 9985                  € 290.000     4        100.0    1      2
# 9986                  € 690.000     3        100.0    1      A
# 9987                  € 539.000     3        125.0    1      3
# 9988                  € 315.000     4        130.0    2      1
# 9989                  € 359.000     3         70.0    1      1
# 9990                  € 149.000     3         60.0    1      T
# 9991                  € 275.000     3         80.0    1      4
# 9992                  € 139.000     2         65.0    1      1
# 9993                  € 159.000     2         50.0    1      1
# 9994                  € 299.000     3         90.0    2      R
# 9995                  € 110.000     2         35.0    1      1
# 9996                   € 68.000     1         20.0    1      4
# 9997                  € 839.000     4        170.0    2      2
# 9998                  € 189.000     3         85.0    1      T
# 9999                  € 520.000     3         86.0    1      1
#
#                                             Description
# 0     PAPILLO EUR in elegante complesso residenziale...
# 1     Rif: 18083 - TORREVECCHIA - Via Ezio Sciamanna...
# 2     San Giovanni, Attico in Vendita, via Taranto l...
# 3     Nel quartiere Monteverde, a poche decine di me...
# 4     Gregorio Settimo - San Damaso \r\nNelle immedi...
# 5     Rif: 18094 - CASILINA - Via Raffaele De Ferrar...
# 6     Rif: 18067 - CENTOCELLE - Via delle Palme. Nel...
# 7     PIAZZALE CLODIO \r\nSiamo a proporvi uno splen...
# 8     Rif: 18028 - TORRE MAURA - Via Silicella. Nell...
# 9     Nel quartiere di Monteverde Nuovo, più precisa...
# 10    Nell’esclusivo quartiere Parioli, e precisamen...
# 11    In Viale delle Mura Gianicolensi, proponiamo i...
# 12    In zona Cinecittà Est, proponiamo la vendita d...
# 13    Rif: 18100 - PISANA - Via Mario Ridolfi. A poc...
# 14    Via Courmayeur, in condominio signorile, immer...
# 15    In strada privata tranquilla e silenziosa, in ...
# 16    In via Del Calice, in zona Capannelle-Statuari...
# 17    In Via Savona, una strada tranquilla nel cuore...
# 18    All'interno del Pentagono dell' Eur Centro e p...
# 19    Prati, appartamento in vendita adiacente Piazz...
# 20    Nella tranquilla e silenziosa Via Ezra Pound, ...
# 21    Montagnola, Appartamento in Vendita, adiacente...
# 22    Rif: Appio Claudio 460 - Viale Tito Labieno al...
# 23    Rif: 18087 - CASILINA - Via Pietro Rovetti. Ne...
# 24    Collatina, Attico in Vendita, tranquillo lumin...
# 25    In Via Sesto Rufo, nelle immediate vicinanze d...
# 26    Nomentana – in via di Pietralata, a 5 minuti d...
# 27    Rif: Quadraro ad. - Via dei Quintili ad.via Co...
# 28    A pochi metri da Piazza Walter Rossi, in via D...
# 29    Villa Bonelli, Appartamento in vendita, nuda p...
# ...                                                 ...
# 9970  Nel cuore di centocelle, a due passi da Piazza...
# 9971  Inserito in un contesto di palazzine in buono ...
# 9972  Case Roma propone in vendita trilocale complet...
# 9973  Case Roma propone in vendita immobile ubicato ...
# 9974  PIGNETO, in palazzina d’epoca, ottima posizion...
# 9975  Rif: MCC16.10.8 - *****IMMOBILASTE ITALIA ****...
# 9976  Rif: roberto - san giovanni porta metronia adi...
# 9977  Rif: alberto - CASILINA ADIACENZE FILARETE IN ...
# 9978  Rif: roberto - borgo pio angolo colonnato in p...
# 9979  Grazioso bilocale con giardino Nei pressi di P...
# 9980  Rif: Val di Non - Nuda Proprietà : in contesto...
# 9981  Mazzini adiacente RAI in prestigioso palazzo d...
# 9982  attico Balduina adiacente piazza Giovenale app...
# 9983  Rif: antonio - COLLI D'ORO VALBONDIONE IN COMP...
# 9984  Rif: alibrandi - Quality Immobiliare propone i...
# 9985  Rif: vg - MONTESACRO- JONIO / Via Veglia \r\nN...
# 9986  Rif: roberto - balduina attico esclusivo ultra...
# 9987  Rif: V200 - In Via Casalmonferrato, elegante e...
# 9988  Appartamento in vendita a Roma Lido di Ostia p...
# 9989  Rif: MS1 - TALENTI / VIA ROBERT MUSIL 8 \r\nLa...
# 9990  In un contesto residenziale proponiamo triloca...
# 9991  Si trova in una traversa di via di Grottarossa...
# 9992  si trova in una traversa di via cassia all'alt...
# 9993  Si trova in una traversa di via Cassia, altezz...
# 9994  Rif: 21 - EUR TORRINO, VIA FIUME GIALLO - In z...
# 9995  Si trova in via Gradoli, una strada privata e ...
# 9996  Si trova in una traversa di via cassia altezza...
# 9997  Rif: RM1703 - San Giovanni, Re di Roma, in Pia...
# 9998  Rif: 14/18 - Cassia Tomba di Nerone, precisame...
# 9999  Piazza del popolo - Proponiamo in palazzo d'ep...
#
# [10000 rows x 8 columns]

# %% [markdown]
# ### CLEANING THE DATASET
#
# Now we have to clean the dataset, and we clean it as follows:
#
# 1) We drop the columns we don't need for the matrices.
#
# 2) We replace the €,+,. symbols in every column.
#
# 3) We drop every row with 'Piano' values that are not digit.
#
# 4) We drop every row with 'Price' values that are longer than 7, because we can't find an house with 10000000€ of price in Rome
#
# 5) We drop all the Nan values

# %%
df1 = df.drop(columns = ['Unnamed: 0','Title'])

df1 = df1.replace('€','', regex = True)

df1 = df1[df1['Piano'].apply(lambda x: str(x).isdigit())]

df1['Price'] = list(map(lambda x: x.replace('.',''),df1['Price']))
df1['Locali'] = list(map(lambda x: x.replace('+',''),df1['Locali']))
df1['Bagni'] = list(map(lambda x: x.replace('+',''),df1['Bagni']))

df1 = df1[df1['Price'].apply(lambda x: len(str(x)) <= 7)]

# %% [markdown]
# ### MATRIX 1

# %% [markdown]
# Now we consider the dataframe without the descriprion column, and we build the first matrix.

# %%
df2 = df1.drop(columns = ['Description'])

df2.dropna()
# Out:
#         Price Locali  Superficie Bagni Piano
# 0      225000     2         50.0    1      1
# 6      149000     3         75.0    1      1
# 8      115000     2         58.0    1      3
# 9      695000     5        250.0    3      3
# 12     370000     4        139.0    2      5
# 13     359000     4        130.0    3      3
# 14     650000     5        170.0    3      1
# 15     800000     5        220.0    3      4
# 16     650000     5        193.0    3      4
# 17     339000     2         70.0    1      3
# 19     950000     5        170.0    1      3
# 22     460000     4        110.0    2      1
# 26     395000     5        130.0    2      1
# 30     385000     3        100.0    3      2
# 31     269000     4        128.0    2      3
# 32     339000     3         90.0    1      4
# 33     745000     5        230.0    3      4
# 36     238000     2         40.0    1      7
# 38     260000     3         78.0    2      1
# 41     895000     5        200.0    3      3
# 43     539000     4        140.0    2      3
# 46     930000     5        150.0    2      3
# 47     449000     4        120.0    2      4
# 48     850000     5        204.0    2      3
# 51     119000     2         65.0    1      1
# 52     620000     2         65.0    1      3
# 53     229000     2         70.0    1      5
# 54     800000     3        125.0    2      5
# 56     690000     4        127.0    2      1
# 57     289000     2         65.0    1      5
# ...       ...    ...         ...   ...   ...
# 9950   199000     2         59.0    1      1
# 9951   300000     4         70.0    1      1
# 9954   258000     4        105.0    2      2
# 9955   219000     3         85.0    1      2
# 9957   690000     5        110.0    2      4
# 9958   750000     5        135.0    3      3
# 9962   215000     3        110.0    2      1
# 9965   239000     3         90.0    1      1
# 9966   770000     5        160.0    2      3
# 9967   130000     3         70.0    1      1
# 9968   119000     2         50.0    1      3
# 9971   239000     4        128.0    2      2
# 9972   199000     3         80.0    2      2
# 9975   125000     2         48.0    1      1
# 9977   150000     2         55.0    1      5
# 9978   690000     3        100.0    2      3
# 9981   860000     5        200.0    2      1
# 9982   660000     4        158.0    2      4
# 9983   279000     4        110.0    2      2
# 9985   290000     4        100.0    1      2
# 9987   539000     3        125.0    1      3
# 9988   315000     4        130.0    2      1
# 9989   359000     3         70.0    1      1
# 9991   275000     3         80.0    1      4
# 9992   139000     2         65.0    1      1
# 9993   159000     2         50.0    1      1
# 9995   110000     2         35.0    1      1
# 9996    68000     1         20.0    1      4
# 9997   839000     4        170.0    2      2
# 9999   520000     3         86.0    1      1
#
# [6359 rows x 5 columns]

# %% [markdown]
# In the next two cells we convert the dataframe in a matrix, because the homework said we have to work with matrices.

# %%
col = ['Price','Locali','Superficie','Bagni','Piano']
m = df2.as_matrix(columns = col)
# Out:
# C:\Users\david\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
mat = np.matrix(m).astype(float)
mat
# Out:
# matrix([[2.25e+05, 2.00e+00, 5.00e+01, 1.00e+00, 1.00e+00],
#         [1.49e+05, 3.00e+00, 7.50e+01, 1.00e+00, 1.00e+00],
#         [1.15e+05, 2.00e+00, 5.80e+01, 1.00e+00, 3.00e+00],
#         ...,
#         [6.80e+04, 1.00e+00, 2.00e+01, 1.00e+00, 4.00e+00],
#         [8.39e+05, 4.00e+00, 1.70e+02, 2.00e+00, 2.00e+00],
#         [5.20e+05, 3.00e+00, 8.60e+01, 1.00e+00, 1.00e+00]])

# %% [markdown]
# Now we implement the Elbow method by using the sklearn library to find the better k (k is number of clusters).
# The Elbow method is a method of interpretation and validation of consistency within cluster analysis designed to help finding the appropriate number of clusters in a dataset.
#
# We have to choose a number of clusters so that adding another cluster doesn't give much better modeling of the data. When we plot the percentage of variance explained by the clusters against the number of clusters, the first clusters will add much information (explain a lot of variance), but at some point the marginal gain will drop, giving an angle in the graph. The number of clusters is chosen at this point, hence the "elbow criterion".
#
# Since this is a visual method, so we need to visualize the curve to find the better number of clusters.

# %%
sse = []
for k in range (2,20):
    kmeans = KMeans(n_clusters=k, random_state = 0).fit(mat)
    sse.append(kmeans.inertia_)
    
fig = plt.figure(figsize=(15,5))
plt.plot(range(2,20), sse, marker = 'o')
plt.grid(True)
plt.title('Elbow Curve')
# Out:
# Text(0.5,1,'Elbow Curve')

# %% [markdown]
# Now we will have the array (with lenght the number of rows of the matrix) and each element of the array will have the number of the cluster to which it belongs.
# We define also a function that count the number of occurences and then it will give the dictionary with the cluster as key and the number of records belonging to this cluster as value.

# %%
kmeans = KMeans(n_clusters=4, random_state = 0).fit(mat)
arr = kmeans.labels_

# %%
def clusval(arr):
    
    d = {}
    for i in range(len(arr)):
        if arr[i] not in d:
            d[arr[i]] = 1
        else:
            d[arr[i]] = d[arr[i]] + 1
    return d


clusval(arr)
# Out:
# {2: 2544, 1: 689, 0: 1958, 3: 1168}

# %%
arr
# Out:
# array([2, 2, 2, ..., 2, 1, 3])

# %% [markdown]
# At this point, to make the wordcloud using the clusters, we need to save in a dictionary, for each key (keys are the clusters),
# the index of the row of the dataframe belonging to that cluster.

# %%
d1={}
for idx,i in enumerate(arr):
    d1.setdefault(i, []).append(idx)
#dictionary with keys the clusters' names, and values the lits of the indices of the announcements in that cluster

# %% [markdown]
# ### MATRIX 2

# %% [markdown]
# Now we have to build the second matrix, and we have to consider the "Description" column of the clean dataframe.

# %%
desc = df1['Description']
leng = len(desc)
print(leng)
print(len(desc.dropna()))
# Out:
# 6359
# 6359

# %% [markdown]
# We see that there are no Nan values in the description.

# %% [markdown]
# Now let's do some preprocessing.
#
# To preprocess the data in this case, we built some functions:
#
# 1) The first function removes stopwords from the italian language.
#
# 2) The second function removes punctuation from list of tokenized words.
#
# 3) The third function stems words in a list of tokenized words.
#
# 4) The fourth function converts all characters to lowercase from a list of tokenized words.
#
# 5) The fifth function replaces all integers occurences in list of tokenized words with textual representation.
#
# In the end, we create a function that recall all the previous function and therefore preprocessed the data.

# %%
def remove_stopwords(wrd):
    new_wrd = [] #List of updated words
    
    for word in wrd:
        if word not in stopwords.words('italian'): # If the current word is not a stopword (ckeck using nltk)
            new_wrd.append(word)                   #appends it to the list
  
    return new_wrd


def remove_punctuation(wrd):
    new_wrds = []  #List of updated words
    
    for word in wrd:
        new_wrd = re.sub(r'[^\w\s]', '', word) # Replaces all punctuation word with "" using RegEx
        if new_wrd != '':
            new_wrds.append(new_wrd)           #And then appends all words different from "" to the list 
    
    return new_wrds


def stem_words(wrd):
    stemmer = SnowballStemmer('italian') # Selects the stemmmer from nltk
    stems = [] # List of updated words
    
    for word in wrd:
        stem = stemmer.stem(word) # Stems the word
        stems.append(stem)        # and appends it to the list
        
    return stems



def to_lowercase(wrd):
    new_wrds = [] # List of updated words
    
    for word in wrd:
        new_wrd = word.lower()   # Converts the current word to lower case
        new_wrds.append(new_wrd) # And append it to the list
        
    return new_wrds




def replace_numbers(wrd):
    
    new_wrds = [] # List of updated words

    for word in wrd:
        if word.isdigit(): # If the current word is a number
            new_wrd = num2words.num2words(int(word),lang='it') # Converts it to its textual representation
            new_wrds.append(new_wrd) # And appends it to the list
        else:
            new_wrds.append(word) # If the current word is not a number appends it to the list
            
    return new_wrds



def preProcessing (x):
    #x.fillna("*", inplace = True) # fills NA with "*"
    #if xt != "*":
        
    xt = nltk.word_tokenize(x) # Tokenizes query using nltk
    
    # Uses previous functions    
    xt = replace_numbers(xt)
    xt = remove_stopwords(xt)
    xt = remove_punctuation(xt)
    xt = stem_words(xt)
    xt = to_lowercase(xt)
   
    return xt

# %%
pdesc = desc.apply(preProcessing)

# %%
pdesc.head()
# Out:
# 0     [papill, eur, eleg, compless, residenzial, rif...
# 6     [rif, diciottomilasessantasett, centocell, via...
# 8     [rif, diciottomilaventott, torr, maur, via, si...
# 9     [nel, quart, monteverd, nuov, precis, via, edo...
# 12    [in, zon, cinecitt, est, propon, vend, appart,...
# Name: Description, dtype: object

# %% [markdown]
# Now we can create a vocabulary as in the previous homework, which associates for each word an id with and the number of documents in which it appears.

# %%
def create_vocabulary(pdesc):
    vocabulary = {} # The vocabulary is a dictionary of the form "Word : (word_id,numberofdocs)"
    inverted_index= {}
    wid = 0 # word_id
    for line in pdesc: 
        for word in set(line):
            if not word in list(vocabulary.keys()) : # if the word is not in the dic
                vocabulary[word] = (wid,1) # adds it
                wid += 1 # Update word_id
            else:
                a, b = vocabulary[word]
                vocabulary[word] = (a,b+1)
    return vocabulary

# %%
voc = create_vocabulary(pdesc)

# %% [markdown]
# Let's see an example and the numner of words we have

# %%
print(len(voc))
voc['angol']
# Out:
# 18644
# (1, 1257)

# %% [markdown]
# Now the next step is to create the IDFi function and then to create the second matrix.

# %%
def IDFi(term):
    return math.log10(leng/voc[term][1])

# %%
idfi = []
for term in voc:
    idfi.append(IDFi(term))

# %%
idfi[:5]
# Out:
# [2.0630261354893698,
#  0.7040535472976557,
#  2.039960831420676,
#  1.9838448894417449,
#  1.3640561311533508]

# %% [markdown]
# Here we finally build the second matrix. We normalize the idfi and append the tfidf in the second matrix, as requested.

# %%
nwords= len(voc)
mat2=np.zeros((leng,nwords))
for idx,line in enumerate(pdesc):
    for word in set(line):
        wid = voc[word][0]
        tfidf = line.count(word)/len(line)*idfi[wid]
        mat2[idx,wid] = tfidf

# %%
'''with open('matrix2', 'wb') as f:
    x = pickle.dump(mat2,f)'''

# %% [markdown]
# Now we can reload the matrix without run:

# %%
with open('matrix2', 'rb') as f:
    mat2 = pickle.load(f)

# %%
mat2.shape
# Out:
# (6359, 18644)

# %% [markdown]
# Now let's reapply the Elbow method, as done for the first matrix, for the second one but we have a lot of columns in this case.

# %%
sse2 =[]
for k in range (2,20):
    kmeans2 = KMeans(n_clusters=k, random_state = 0).fit(mat2)
    sse2.append(kmeans2.inertia_)
    
fig = plt.figure(figsize=(15,5))
plt.plot(range(2,20), sse2, marker = 'o')
plt.grid(True)
plt.title('Elbow Curve')
# Out:
# Text(0.5,1,'Elbow Curve')

# %% [markdown]
# As we expected, the method for this matrix should be applied by iterating the number of clusters (k), for numbers much larger than k.
# In fact, as we can see, the curve does not follow the trend shown for the first matrix and we can not see for what k it tends to 0 from the graph that we plotted.
#
# Probably the optimal number of clusters in this case would have been about a thousand, but it would make absolutely no sense to consider a thousand clusters for a dataframe of just over 6000 lines (besides being senseless it is also extremely slow as a process).
#
# To better compare the results on the clusters of the two matrices, let's consider also for this matrix the same number as the first one, then k = 4.

# %%
kmeans2 = KMeans(n_clusters=4, random_state = 0).fit(mat2)
arr2 = kmeans2.labels_

# %%
clusval(arr2)
# Out:
# {3: 5056, 2: 1218, 1: 54, 0: 31}

# %% [markdown]
# As we did for the first matrix clusters, now we build a dictionary where the keys are the second matrix clusters names and the values are the announcements that belong to that cluster.

# %%
d2={}
for idx,i in enumerate(arr2):
    d2.setdefault(i, []).append(idx)
#dictionary with keys the clusters' names, and values the lits of the indices of the announcements in that cluster

# %% [markdown]
# ## WORDCLOUD

# %% [markdown]
# Here we compute the Jaccard similarity between the first clusters and the second ones.
#
# The Jaccard coefficient measures the similarity between sample sets, and is defined as the dimension of the intersection divided by the size of the union of the sample sets.
#
# So we implement the Jaccard similarity between our clusters and choose the three pairs of clusters that have a higher similarity.

# %%
similarity = np.zeros((4,4))
for i in range (4):
    for j in range(4):
        Si = set(d1[i])
        Sj = set(d2[j])
        sim = (len(Si.intersection(Sj))/len(Si.union(Sj)))
        similarity[i,j] = sim
        similarity[j,i] = sim
similarity
# Out:
# array([[0.00201511, 0.        , 0.00940808, 0.00250836],
#        [0.        , 0.00405405, 0.0073672 , 0.00741962],
#        [0.00940808, 0.0073672 , 0.18975332, 0.08652095],
#        [0.00250836, 0.00741962, 0.08652095, 0.18372005]])

# %%
similarity2 = similarity
couples = []
for i in range (3):
    maxx = np.unravel_index(np.argmax(similarity2), similarity2.shape)
    couples.append(maxx)
    similarity2[maxx] = 0

couples
# Out:
# [(2, 2), (3, 3), (2, 3)]

# %% [markdown]
# ### First couple

# %% [markdown]
# Now we have to make Wordclouds with the three couples of cluster we have from the previous task.
#
# The words that will be represented are those extracted from the description of the houses that are in the relative couple, so we have to make an intersection between the couple of cluster (to find the documents in common between the two clusters), then extract all the description of these documents and we use the wordcloud library to visualize these words.

# %%
a = set(d1[2])
b = set(d2[2])

intersect1 = list(a.intersection(b))

# %%
text1 =''
for i in range(len(intersect1)):
    text1 = text1 + df.iloc[intersect1[i]]['Description']

# %%
def strip_punctuation(s):
    return ''.join(c for c in s if c not in punctuation)

text1 = strip_punctuation(text1)

# %%
mask = np.array(Image.open("house.png"))

# %%
stop = set(stopwords.words('italian'))
stop = list(stop)

# %%
stop # list of the italian stopwords: to give as argument in the wordcloud function to drop them!
# Out:
# ['del',
#  'con',
#  'faceva',
#  'starete',
#  'nello',
#  'dagl',
#  'voi',
#  'avremmo',
#  'fossimo',
#  'dov',
#  'saremmo',
#  'mi',
#  'starai',
#  'hanno',
#  'dagli',
#  'sareste',
#  'quale',
#  'stavi',
#  'loro',
#  'di',
#  'ebbero',
#  'ma',
#  'quella',
#  'fossero',
#  'starò',
#  'avesse',
#  'sul',
#  'cui',
#  'mio',
#  'avessimo',
#  'facciate',
#  'starà',
#  'vostro',
#  'steste',
#  'avendo',
#  'fosti',
#  'tua',
#  'tue',
#  'avevi',
#  'saresti',
#  'avevano',
#  'tutto',
#  'avessero',
#  'sugli',
#  'quello',
#  'a',
#  'avrai',
#  'eravate',
#  'sugl',
#  'delle',
#  'fecero',
#  'facesti',
#  'essendo',
#  'agl',
#  'o',
#  'staresti',
#  'sta',
#  'miei',
#  'se',
#  'nostre',
#  'vostra',
#  'stavo',
#  'saremo',
#  'noi',
#  'ha',
#  'avevate',
#  'stessero',
#  'agli',
#  'sulla',
#  'abbiano',
#  'lei',
#  'facciamo',
#  'perché',
#  'sui',
#  'nelle',
#  'questa',
#  'stai',
#  'staranno',
#  'quanto',
#  'avemmo',
#  'nel',
#  'è',
#  'l',
#  'stiamo',
#  'avete',
#  'la',
#  'fui',
#  'sarò',
#  'facevi',
#  'feci',
#  'foste',
#  'vostri',
#  'facessero',
#  'fossi',
#  'facevate',
#  'dalle',
#  'fanno',
#  'sarà',
#  'quanta',
#  'sono',
#  'abbiamo',
#  'farebbero',
#  'facevamo',
#  'questo',
#  'quanti',
#  'i',
#  'dalla',
#  'fummo',
#  'aveste',
#  'uno',
#  'faremo',
#  'stando',
#  'stava',
#  'sull',
#  'stanno',
#  'stesse',
#  'io',
#  'aveva',
#  'al',
#  'suoi',
#  'su',
#  'le',
#  'farò',
#  'faremmo',
#  'starebbe',
#  'sarai',
#  'faresti',
#  'un',
#  'quelle',
#  'si',
#  'ed',
#  'e',
#  'stia',
#  'ai',
#  'avresti',
#  'avrete',
#  'sulle',
#  'coi',
#  'allo',
#  'sue',
#  'avuta',
#  'siamo',
#  'stesti',
#  'da',
#  'mie',
#  'ebbe',
#  'della',
#  'sia',
#  'lo',
#  'facciano',
#  'ad',
#  'in',
#  'tra',
#  'avute',
#  'dall',
#  'erano',
#  'avuti',
#  'siete',
#  'queste',
#  'abbiate',
#  'all',
#  'era',
#  'non',
#  'eravamo',
#  'nostra',
#  'fu',
#  'facesse',
#  'dell',
#  'che',
#  'negl',
#  'fece',
#  'ci',
#  'il',
#  'alle',
#  'tu',
#  'stavano',
#  'facendo',
#  'stavamo',
#  'come',
#  'c',
#  'faccio',
#  'dei',
#  'avevo',
#  'fosse',
#  'stiano',
#  'dallo',
#  'stettero',
#  'ho',
#  'siano',
#  'sarebbe',
#  'nella',
#  'ne',
#  'fai',
#  'avuto',
#  'stiate',
#  'quelli',
#  'sua',
#  'siate',
#  'più',
#  'hai',
#  'faranno',
#  'tutti',
#  'fareste',
#  'sto',
#  'vostre',
#  'col',
#  'anche',
#  'li',
#  'avrebbero',
#  'avesti',
#  'eri',
#  'facevo',
#  'contro',
#  'chi',
#  'ti',
#  'una',
#  'ero',
#  'farà',
#  'faccia',
#  'lui',
#  'abbia',
#  'facemmo',
#  'staremo',
#  'stemmo',
#  'avreste',
#  'stessimo',
#  'tuoi',
#  'degli',
#  'dello',
#  'vi',
#  'farete',
#  'stessi',
#  'suo',
#  'starei',
#  'avessi',
#  'avrei',
#  'avrebbe',
#  'dal',
#  'gli',
#  'avranno',
#  'stette',
#  'negli',
#  'alla',
#  'ebbi',
#  'starebbero',
#  'dai',
#  'tuo',
#  'furono',
#  'nei',
#  'questi',
#  'sullo',
#  'sarebbero',
#  'avevamo',
#  'nostri',
#  'stetti',
#  'saranno',
#  'degl',
#  'facevano',
#  'per',
#  'sei',
#  'farebbe',
#  'nell',
#  'avrò',
#  'avremo',
#  'staremmo',
#  'stareste',
#  'stavate',
#  'faceste',
#  'quante',
#  'nostro',
#  'avrà',
#  'sarete',
#  'sarei',
#  'farai',
#  'farei',
#  'facessi',
#  'facessimo',
#  'mia',
#  'dove']

# %%
wordcloud1 = WordCloud(mask=mask, background_color="white",max_words=1000, stopwords = stop, contour_width =3, contour_color='firebrick').generate(
           text1)

# %%
plt.figure(figsize=(20, 10))
plt.imshow(wordcloud1, interpolation = 'bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### Second couple

# %%
c = set(d1[3])
d = set(d2[3])

intersect2 = list(c.intersection(d))

# %%
text2 = ''
for i in range(len(intersect2)):
    text2 = text2 + df.iloc[intersect2[i]]['Description']

# %%
text2 = strip_punctuation(text2)

# %%
wordcloud2 = WordCloud(mask=mask, background_color="white",max_words=1000, stopwords = stop, contour_width =3, contour_color='firebrick').generate(
           text2)

# %%
plt.figure(figsize=(20, 10))
plt.imshow(wordcloud2, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### Third couple

# %%
e = set(d1[2])
f = set(d2[3])

intersect3 = list(e.intersection(f))

# %%
text3 =''
for i in range(len(intersect3)):
    text3 = text3 + df.iloc[intersect3[i]]['Description']

# %%
text3 = strip_punctuation(text3)

# %%
wordcloud3 = WordCloud(mask=mask, background_color="white", max_words=1000, stopwords = stop, contour_width = 3, contour_color ='firebrick').generate(
           text3)

# %%
plt.figure(figsize=(20, 10))
plt.imshow(wordcloud3, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # PART-2: PASSWORD
