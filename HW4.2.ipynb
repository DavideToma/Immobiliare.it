# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
import time
import re
#price,locali,superficie,bagni,piano
df = pd.DataFrame(columns=["Title", "Price","Locali","Superficie","Bagni","Piano","Description"])
address =  "https://www.immobiliare.it/vendita-case/roma/?criterio=rilevanza&pag="
page = "https://www.immobiliare.it/"

# %%
count=0
row=0
for i in range(649,650):
    address = "https://www.immobiliare.it/vendita-case/roma/?criterio=rilevanza&pag="+str(i)
    url = requests.get(address)
    page =BeautifulSoup(url.text, 'lxml') 
    x = page.findAll('ul',{'class','annunci-list'})[0]
    
    types = ["vetrina","star","top","premium"]
    
    for t in types:
        
        for y in x.find_all('li', {'class', 'listing-item '+t+' js-row-detail'}):
            try:
                content = y.find('div',class_='listing-item_body--content')
                title = content.p.a.attrs
                if title['href'][:5]=="https":
                    site= title["href"]
                else:
                    site = 'https://www.immobiliare.it' + title['href']
                url2 = requests.get(site)
                page2 = BeautifulSoup(url2.text, 'lxml')
                descr = page2.find('div',class_='col-xs-12 description-text text-compressed')
                description = descr.div.text.strip()
                price = content.find('li', class_='lif__item lif__pricing').text
                locali_superficie = content.find_all(class_= 'text-bold')
                locali = locali_superficie[0].text
                superficie = locali_superficie[1].text
                bagni = locali_superficie[2].text
                piano = locali_superficie[3].text.strip()
                if len(piano)>3:
                    raise
                #garantito = content.find('li',class_='lif__item lif__guaranteed').text
                #description = content.find('div',class_="descrizione").text
                #print(title['title'])
                #print(description)

                #df.loc[row] = [title['title'],price.strip(),locali,superficie,bagni,piano,description]
                #row+=1

            except:
                #print("Not considering a column")
                count+=1

            


    #print("Page Number:"+str(i))

#df.to_csv("scrape.csv")

# %%
df
# Out:
#                                                   Title  \
# 0     Bilocale viale Italo Calvino, Fonte Ostiense, ...
# 1     Quadrilocale via Alessandro Fleming, Fleming, ...
# 2     Attico / Mansarda largo Arturo Donaggio, Torre...
# 3     Bilocale viale delle Medaglie d'Oro 124, Medag...
# 4     Trilocale via Fontanellato 75, Ardeatino - Mon...
# 5             Bilocale via Savona, Villa Fiorelli, Roma
# 6     Attico / Mansarda piazzale delle Medaglie d'Or...
# 7     Quadrilocale via Cristoforo Sabbadino, Piana d...
# 8      Appartamento via Lucio Apuleio 9, Balduina, Roma
# 9     Trilocale via Carlo Dapporto 38, Porta di Roma...
# 10    Trilocale piazza San Giovanni in Laterano 3741...
# 11    Appartamento via della Tribuna di Campitelli, ...
# 12    Trilocale via Mattia Battistini 220C, Battisti...
# 13    Appartamento piazza Camillo Benso di Cavour, P...
# 14    Appartamento via del Giuba, Africano - Villa C...
# 15    Appartamento viale dell'Oceano Atlantico 250, ...
# 16       Trilocale via Arnaldo Cantani, Massimina, Roma
# 17          Quadrilocale via Dacia 22, Re di Roma, Roma
# 18    Bilocale via della Camilluccia, Camilluccia - ...
# 19    Bilocale via della Camilluccia, Camilluccia - ...
# 20    Attico / Mansarda viale delle Medaglie d'Oro 2...
# 21    Quadrilocale viale della Grande Muraglia 540, ...
# 22      Trilocale via Antonio Ciamarra, Cinecittà, Roma
# 23    Trilocale via dei Banchi Vecchi, Via Giulia, Roma
# 24    Quadrilocale via dei Chiavari, Campo de' Fiori...
# 25    Quadrilocale viale Bruno Pelizzi 281, Cinecitt...
# 26    Bilocale via Federico Turano 57, Tor Sapienza ...
# 27    Appartamento via di San Bartolomeo de' Vaccina...
# 28    Appartamento via dei Colli della Farnesina 8, ...
# 29    Attico / Mansarda via dei Baullari, Campo de' ...
# ...                                                 ...
# 3852                Bilocale via Eistein, Marconi, Roma
# 3853  Trilocale via della Pineta Sacchetti 229, Geme...
# 3854  Quadrilocale via dell'Orsa Minore 42, Torrino,...
# 3855  Trilocale buono stato, primo piano, Settebagni...
# 3856  Trilocale buono stato, settimo piano, Casal Br...
# 3857         Appartamento via Fregene, Re di Roma, Roma
# 3858        Bilocale via veientana vetere, Labaro, Roma
# 3859  Appartamento via Nemorense, Africano - Villa C...
# 3860  Quadrilocale via Ferretti, Talenti - Monte Sac...
# 3861  Appartamento via Piediluco, Trieste - Coppedè,...
# 3862  Bilocale adiacente via Filarete, Torpignattara...
# 3863             Trilocale viale Parioli, Parioli, Roma
# 3864               Appartamento via Cavour, Monti, Roma
# 3865  Quadrilocale via Valdinievole, Città Giardino,...
# 3866  Loft / Open Space piazza Nicosia, Montecitorio...
# 3867  Trilocale buono stato, quinto piano, Battistin...
# 3868         Appartamento via Curioni, Pietralata, Roma
# 3869  Trilocale via Dicomano, Cassia - San Godenzo, ...
# 3870  Attico / Mansarda via Francesco Pallavicini, P...
# 3871        Quadrilocale terzo piano, San Lorenzo, Roma
# 3872       Trilocale via Giustiniana, Prima Porta, Roma
# 3873  Trilocale ottimo stato, secondo piano, Campo d...
# 3874  Appartamento buono stato, sesto piano, Monti, ...
# 3875  Appartamento ottimo stato, terzo piano, Euclid...
# 3876  Trilocale via degli Spagnoli 29, Montecitorio,...
# 3877  Trilocale via Fonteiana, Monteverde Vecchio, Roma
# 3878  Bilocale via Oderisi da Gubbio 200, Marconi, Roma
# 3879  Bilocale ottimo stato, sesto piano, Parioli, Roma
# 3880  Attico / Mansarda buono stato, 70 mq, Talenti ...
# 3881  Trilocale ottimo stato, primo piano, Trullo - ...
#
#                          Price Locali Superficie Bagni Piano  \
# 0                    € 225.000     2          50    1      1
# 1                  € 1.350.000     4         200    2      2
# 2                    € 135.000     2          60    1      5
# 3                    € 249.000     2          75    1      1
# 4                    € 279.000     3         110    1      T
# 5                    € 339.000     2          70    1      3
# 6                    € 699.000    5+         174    3      A
# 7                    € 189.000     4         168   3+      T
# 8                    € 570.000     5         160    2      2
# 9                    € 215.000     3          67    1      1
# 10                   € 339.000     3          90    1      4
# 11                 € 3.700.000    5+         250   3+      5
# 12                   € 279.000     3         100    2      1
# 13                   € 549.000     5          85    2      2
# 14                 € 1.700.000    5+         460   3+      T
# 15                   € 579.000     5         160    2      2
# 16                   € 269.000     3          87    2      3
# 17                   € 480.000     4         125    2      4
# 18                   € 169.000     2          58    1      T
# 19                   € 169.000     2          58    1      T
# 20                   € 238.000     2          40    1      7
# 21                   € 250.000     4         110    2      A
# 22                   € 325.000     3         100    2      5
# 23                   € 680.000     3          90    1      3
# 24                   € 849.000     4         127    1      2
# 25                   € 370.000     4         139    2      5
# 26                   € 165.000     2          78    1      4
# 27                 € 1.100.000    5+         154    1      3
# 28                 € 1.070.000    5+         230   3+      1
# 29                 € 1.050.000    5+         235    3      3
# ...                        ...    ...        ...   ...   ...
# 3852                 € 235.000     2          70    1      8
# 3853                 € 420.000     3          90    1      1
# 3854                 € 419.000     4         120    2      1
# 3855                 € 189.000     3          82    1      1
# 3856                 € 195.000     3          63    1      7
# 3857                 € 450.000     5         145    2      4
# 3858                 € 205.000     2          80    1      T
# 3859                 € 590.000     5         160    2      4
# 3860                 € 625.000     4         120    2      T
# 3861               € 1.150.000    5+         200    3      R
# 3862                 € 129.000     2          40    1      T
# 3863                 € 360.000     3          75    1      T
# 3864               € 1.250.000    5+         190    3      3
# 3865                 € 280.000     4         110    2      2
# 3866  € 245.000€ 285.000(-14%)     1          36    1      T
# 3867                 € 139.000     3          66    1      5
# 3868                 € 470.000     5         135    2      2
# 3869                 € 500.000     3         105    2      A
# 3870                 € 280.000     3          75    1      5
# 3871                 € 378.000     4          95    2      3
# 3872                 € 295.000     3         120    2      T
# 3873                 € 650.000     3          82    1      2
# 3874               € 1.250.000     5         235    3      6
# 3875                 € 920.000     5         165    2      3
# 3876                 € 790.000     3          80    2      3
# 3877                 € 650.000     3         160    2      3
# 3878                 € 250.000     2          90    1      4
# 3879                 € 730.000     2          89    1      6
# 3880                 € 208.000     2          70    1      A
# 3881                 € 269.000     3          90    1      1
#
#                                             Description
# 0     PAPILLO EUR in elegante complesso residenziale...
# 1     FLEMING - IN STRADA PRIVATA - VIA ALESSANDRO F...
# 2     Torrevecchia, adiacente Largo Arturo Donaggio,...
# 3     Balduina, adiacente Piazza Giovenale, appartam...
# 4     Rif: 18101 - MONTAGNOLA - Via Fontanellato. A ...
# 5     In Via Savona, una strada tranquilla nel cuore...
# 6     Balduina, Appartamento in Vendita, adiacente P...
# 7     complesso isla bianca\nnella zona denomina le ...
# 8     In una delle vie più servite e silenziose dell...
# 9     Rif: 18105 - PORTA DI ROMA - Via Carlo Dapport...
# 10    San Giovanni, Appartamento in Vendita, finemen...
# 11    Rione Campitelli, adiacente al Teatro di Marce...
# 12    Pineta Sacchetti, Appartamento in Vendita, adi...
# 13    Prati, appartamento in vendita adiacente Piazz...
# 14    Nel cuore dei quartieri Trieste e Africano ed ...
# 15    Eur, Appartamento in vendita via Cesare Pavese...
# 16    CASAL LUMBROSO - AURELIA - 3° PIANO - MQ 87 - ...
# 17    Rif: 18091 - SAN GIOVANNI - Via Dacia. Nelle i...
# 18    Camilluccia, ottimo investimento, Appartamento...
# 19    Camilluccia, ottimo investimento, Appartamento...
# 20    Adiacente ai servizi ed alle molteplici attivi...
# 21    Eur, appartamento in vendita, adiacenze Via de...
# 22    Rif: 883P - Cinecittà, appartamento in vendita...
# 23    CENTRO STORICO - VIA DEI BANCHI VECCHI Proponi...
# 24    Nel cuore del Rione Parione, proponiamo in ven...
# 25    In zona Cinecittà Est, proponiamo la vendita d...
# 26    Rif: 18092 - COLLATINA - La Rustica. Adiacente...
# 27    Il Lungotevere Dè Cenci è il tratto di lungote...
# 28    In Via dei Colli della Farnesina, in prossimit...
# 29    Attico esclusivo su due livelli, tra Piazza de...
# ...                                                 ...
# 3852  Via Eistein immobile posto all'ottavo piano su...
# 3853  PINETA SACCHETTI FRONTE GEMELLI - In comprenso...
# 3854  EUR Torrino Via Dell'Orsa Minore, proponiamo u...
# 3855  Settebagni proponiamo in vendita luminoso appa...
# 3856  ROMA In zona altamente servita e ben collegata...
# 3857  DIGITA WWW BORSINO NET PER IL VIDEO E TUTTE LE...
# 3858  Rif: Veientana Vetere - Labaro Via Veientana V...
# 3859  DIGITA WWW BORSINO NET PER IL VIDEO E TUTTE LE...
# 3860  DIGITA WWW BORSINO NET PER IL VIDEO E TUTTE LE...
# 3861  DIGITA WWW BORSINO NET PER IL VIDEO E TUTTE LE...
# 3862  DIGITA WWW BORSINO NET PER IL VIDEO E TUTTE LE...
# 3863  DIGITA WWW BORSINO NET PER IL VIDEO E TUTTE LE...
# 3864  DIGITA WWW BORSINO NET PER IL VIDEO E TUTTE LE...
# 3865  DIGITA WWW BORSINO NET PER IL VIDEO E TUTTE LE...
# 3866  Piazza Nicosia - Nelle vicinanze di via Ripett...
# 3867  ROMA, Via Mattia Battistini, centrale, adiacen...
# 3868  DIGITA WWW BORSINO NET PER IL VIDEO E TUTTE LE...
# 3869  DIGITA WWW BORSINO NET PER IL VIDEO E TUTTE LE...
# 3870  DIGITA WWW BORSINO NET PER IL VIDEO E TUTTE LE...
# 3871  DIGITA WWW BORSINO NET PER IL VIDEO E TUTTE LE...
# 3872  DIGITA WWW BORSINO NET PER IL VIDEO E TUTTE LE...
# 3873  via dei cappellari - adiacenze piazza campo de...
# 3874  Proponiamo la vendita di un appartamento in un...
# 3875  Rif: PARIOLI - Appartamento al piano terzo di ...
# 3876  Nelle adiacenze di via della Scrofa, vendiamo ...
# 3877  Monteverde Vecchio via Fonteiana appartamento ...
# 3878  MARCONI VIA ODERISI DA GUBBIO IV piano con asc...
# 3879  Piccolo delizioso attico di circa 80 mq con te...
# 3880  talenti edificio fronte parco petroselli deliz...
# 3881  Colle del Sole Via delle Vigne in elegante com...
#
# [3882 rows x 7 columns]

# %%
df.to_csv("3882rows.csv")

# %%
row
# Out:
# 3882

# %%
list(df['Description'])
# Out:
# ['\n                                Le residenze di Rinascimento Quinto completano il programma edilizio Rione Rinascimento, il progetto di città giardino per Roma del Gruppo Pietro Mezzaroma e Figli.\nIl complesso residenziale è concepito per avere il minor impatto ambientale e paesaggistico possibile, così da integrarsi armoniosamente con il verde di Parco Talenti. L’intero quartiere è difatti al centro di una profonda riqualificazione urbana, che fa dell’eco-compatibilità e della ricerca architettonica i suoi punti di maggior forza.\nL’iniziativa prevede la realizzazione di tre edifici distinti. Ogni unità abitativa, in classe energetica A/A+, è finemente rifinita, composta da materiali di prima qualità forniti dalle migliori aziende del settore. L’idea stilistica alla base del progetto prevede l’esaltazione dei volumi esterni con ampie terrazze panoramiche dall’architettura moderna, che sapientemente sfruttano le potenzialità della luce naturale per l’illuminazione degli interni, rendendo gli ambienti sobri e naturali..\nGli appartamenti che compongono Rinascimento Quinto sono tecnicamente all’avanguardia per quanto riguarda il contenimento ed il risparmio energetico. Speciali sistemi domotici di ultima generazione garantiscono una gestione intelligente delle risorse, permettendo di ottenere, in ogni ambiente, un microclima perfetto evitando inutili sprechi..\nAd ogni unità abitativa sono abbinati box e/o posto auto coperto e cantina..\nNumerose strutture condominiali quali piscina scoperta , guardiania, ampie zone a giardino, spazio giochi per bambini e parcheggi esterni completano l’offerta residenziale di Rinascimento Quinto --> www.mezzaroma.it\nTipologia delle residenze:\n- Mono/bilocali da 48 a 60 mq\n- Trilocali da 95 a 107 mq\n- Quadrilocali da 107 a 155 mq\n- Attici di 128 mq.\n\n']

# %%
address = "https://www.immobiliare.it/vendita-case/roma/?criterio=rilevanza&pag=1"
url = requests.get(address)
page = BeautifulSoup(url.text, 'lxml')


content = y.find('div',class_='listing-item_body--content')
title = content.p.a.attrs
site = 'https://www.immobiliare.it' + title['href']
url2 = requests.get(site)
page2 = BeautifulSoup(url2.text, 'lxml')

x = page2.find('div',class_='col-xs-12 description-text text-compressed')
print(x.div.text)
# Out:
#                                 Le residenze di Rinascimento Quinto completano il programma edilizio Rione Rinascimento, il progetto di città giardino per Roma del Gruppo Pietro Mezzaroma e Figli.
# Il complesso residenziale è concepito per avere il minor impatto ambientale e paesaggistico possibile, così da integrarsi armoniosamente con il verde di Parco Talenti. L’intero quartiere è difatti al centro di una profonda riqualificazione urbana, che fa dell’eco-compatibilità e della ricerca architettonica i suoi punti di maggior forza.
# L’iniziativa prevede la realizzazione di tre edifici distinti. Ogni unità abitativa, in classe energetica A/A+, è finemente rifinita, composta da materiali di prima qualità forniti dalle migliori aziende del settore. L’idea stilistica alla base del progetto prevede l’esaltazione dei volumi esterni con ampie terrazze panoramiche dall’architettura moderna, che sapientemente sfruttano le potenzialità della luce naturale per l’illuminazione degli interni, rendendo gli ambienti sobri e naturali..
# Gli appartamenti che compongono Rinascimento Quinto sono tecnicamente all’avanguardia per quanto riguarda il contenimento ed il risparmio energetico. Speciali sistemi domotici di ultima generazione garantiscono una gestione intelligente delle risorse, permettendo di ottenere, in ogni ambiente, un microclima perfetto evitando inutili sprechi..
# Ad ogni unità abitativa sono abbinati box e/o posto auto coperto e cantina..
# Numerose strutture condominiali quali piscina scoperta , guardiania, ampie zone a giardino, spazio giochi per bambini e parcheggi esterni completano l’offerta residenziale di Rinascimento Quinto --> www.mezzaroma.it
# Tipologia delle residenze:
# - Mono/bilocali da 48 a 60 mq
# - Trilocali da 95 a 107 mq
# - Quadrilocali da 107 a 155 mq
# - Attici di 128 mq.

# %%
df
# Out:
# Empty DataFrame
# Columns: [Title, Price, Locali, Superficie, Bagni, Grantito, Description]
# Index: []
